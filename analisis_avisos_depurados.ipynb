# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_avisos = pd.read_csv('../Hackathon ISA/Datasets/avisos_depurado_georreferenciados.csv')
df_avisos.head()
# Out:
# /var/folders/ph/kk5ffp952hx0h94c23f3_n7r0000gn/T/ipykernel_58561/908585636.py:1: DtypeWarning: Columns (11,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_avisos = pd.read_csv('../Hackathon ISA/Datasets/avisos_depurado_georreferenciados.csv')
#    Aviso  Clase de aviso  Area de empresa                Texto codigo accion  \
# 0  33101              M2              NOR             REFUERZO PATA DE TORRE
# 1  33176              M1              NTE        HACER ESTUDIO ESPECIALIZADO
# 2  33184              M1              NTE        HACER ESTUDIO ESPECIALIZADO
# 3  33458              M2              NOR                 CAMBIO DE ELEMENTO
# 4  33562              M2              NOR  COLOCACIÓN DE CAMISAS O BLINDAJES
#
#                             Texto de accion         Fecha inicio  \
# 0        Instalaron vientos estabilizadores  2000-02-15 00:00:00
# 1                                       NaN  2000-06-01 00:00:00
# ...

# %%
df_avisos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111863 entries, 0 to 111862
# Data columns (total 37 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Aviso                                   111863 non-null  object
#  1    Clase de aviso                         104292 non-null  object
#  2    Area de empresa                        104294 non-null  object
#  3    Texto codigo accion                    103470 non-null  object
#  4    Texto de accion                        86510 non-null   object
#  5    Fecha inicio                           90699 non-null   object
#  6    Fecha de fin                           100307 non-null  object
#  7    Modificado el                          39536 non-null   object
#  8    Fin de averia                          30439 non-null   object
#  9   Inicio de averia                        104113 non-null  object
# ...

# %%
df_avisos.columns
# Out:
# Index(['Aviso', ' Clase de aviso', ' Area de empresa', ' Texto codigo accion',
#        ' Texto de accion', ' Fecha inicio', ' Fecha de fin', ' Modificado el',
#        ' Fin de averia', 'Inicio de averia', ' Poblacion',
#        ' Duracion de parada', 'Denominacion de objeto tecnico', 'Creado el',
#        'Texto codigo del problema', ' Texto grupo de codigos para problema',
#        ' Texto posicion', 'Texto codigo p. codificacion',
#        ' Texto grupos codificacion', ' Fin deseado', ' Texto grupo accion',
#        ' Texto codigo parte objeto', 'Texto grupo de codigos p. parte objeto',
#        ' Denominacion de la ubicacion tecnica', ' Texto para prioridad',
#        ' Cierre por fecha', ' Fecha de aviso', ' Descripcion',
#        ' Perfil de catalogo', ' Inicio deseado', 'Status del sistema',
#        ' Ubicacion tecnica', ' Status de usuario', ' Texto breve de material',
#        ' Clave de la ubicacion', 'Coordenada y', 'Coordenada x;;'],
#       dtype='object')

# %%
df_avisos[' Inicio deseado']
# Out:
# 0         2000-02-16
# 1         2000-02-23
# 2         2000-02-24
# 3         2000-02-28
# 4         2000-03-08
#              ...
# 111858    2018-03-27
# 111859    2018-03-20
# 111860    2018-03-21
# 111861    2018-03-23
# 111862    2018-03-22
# Name:  Inicio deseado, Length: 111863, dtype: object

# %%
df_avisos.isnull().sum()
# Out:
# Aviso                                          0
#  Clase de aviso                             7571
#  Area de empresa                            7569
#  Texto codigo accion                        8393
#  Texto de accion                           25353
#  Fecha inicio                              21164
#  Fecha de fin                              11556
#  Modificado el                             72327
#  Fin de averia                             81424
# Inicio de averia                            7750
#  Poblacion                                109902
#  Duracion de parada                         7628
# Denominacion de objeto tecnico             26349
# Creado el                                   7627
# Texto codigo del problema                  86557
#  Texto grupo de codigos para problema      86555
#  Texto posicion                           104373
# Texto codigo p. codificacion               38035
#  Texto grupos codificacion                 38037
# ...

# %%
# Modificar formatos de fecha
df_avisos[' Fecha inicio'] = pd.to_datetime(df_avisos[' Fecha inicio'], format='%Y-%m-%d', errors='coerce')
df_avisos[' Fecha de fin'] = pd.to_datetime(df_avisos[' Fecha de fin'], format='%Y-%m-%d', errors='coerce')
df_avisos[' Modificado el'] = pd.to_datetime(df_avisos[' Modificado el'], format='%Y-%m-%d', errors='coerce')
df_avisos['Inicio de averia'] = pd.to_datetime(df_avisos['Inicio de averia'], format='%Y-%m-%d', errors='coerce')
df_avisos[' Fin de averia'] = pd.to_datetime(df_avisos[' Fin de averia'], format='%Y-%m-%d', errors='coerce')
df_avisos['Creado el'] = pd.to_datetime(df_avisos['Creado el'], format='%Y-%m-%d', errors='coerce')
df_avisos[' Fin deseado'] = pd.to_datetime(df_avisos[' Fin deseado'], format='%Y-%m-%d', errors='coerce')
df_avisos[' Cierre por fecha'] = pd.to_datetime(df_avisos[' Cierre por fecha'], format='%Y-%m-%d', errors='coerce')
df_avisos[' Fecha de aviso'] = pd.to_datetime(df_avisos[' Fecha de aviso'], format='%Y-%m-%d', errors='coerce')
df_avisos[' Inicio deseado'] = pd.to_datetime(df_avisos[' Inicio deseado'], format='%Y-%m-%d', errors='coerce')

# %%
df_avisos = df_avisos.dropna(subset=[' Clase de aviso'])

# %%
# Gráfica clase de avisos
clases_avisos = df_avisos[' Clase de aviso'].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=clases_avisos.index, y=clases_avisos.values, palette='viridis', hue=clases_avisos.index)
plt.xticks(rotation=45)
plt.xlabel('Clase de aviso')
plt.ylabel('Número de avisos')
plt.title('Clases de aviso')
plt.tight_layout()
plt.show()

# %%
# Gráfica de las 30 ubicaciones técnicas más frecuentes (Con clase de aviso)
top_30_ubicaciones = df_avisos.groupby([' Ubicacion tecnica', ' Clase de aviso']).size().nlargest(30).reset_index(name='Frecuencia')

# print(top_30_ubicaciones)

plt.figure(figsize=(12, 8))
sns.barplot(data=top_30_ubicaciones, x=' Ubicacion tecnica', y='Frecuencia', hue=' Clase de aviso', palette='viridis')
plt.xticks(rotation=90)
plt.xlabel('Ubicación técnica')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de Clases de Avisos por Ubicación Técnica (Top 20)')
plt.legend(title='Clase de Aviso', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Gráfica de las primeras 10 áreas encargadas
area_encargada = df_avisos[' Perfil de catalogo'].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=area_encargada.index, y=area_encargada.values, palette='viridis', hue=area_encargada.index)
plt.xticks(rotation=45)
plt.xlabel('Área encargada')
plt.ylabel('Número de avisos')
plt.title('Áreas encargadas')
plt.tight_layout()
plt.show()
